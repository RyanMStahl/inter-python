# %%
with open("data/employees.csv","r") as f:
    text = f.read()
text.split("\n")
# Out:
# ['ID,Name,Department,Salary,Email',
#  '1,Ivy Clark,Operations,49662,ivy.clark@example.com',
#  '2,Grace Miller,IT,61923,grace.miller@example.com',
#  '3,Karen Xu,Sales,109685,karen.xu@example.com',
#  '4,Karen Evans,Finance,105968,karen.evans@example.com',
#  '5,Victor Underwood,Sales,87480,victor.underwood@example.com',
#  '6,Henry Zimmerman,Operations,105242,henry.zimmerman@example.com',
#  '7,Nate Turner,Engineering,115302,nate.turner@example.com',
#  '8,Frank Brown,Support,82794,frank.brown@example.com',
#  '9,Nate Xu,Finance,65897,nate.xu@example.com',
#  '10,Carol Garcia,Marketing,53173,carol.garcia@example.com',
#  '11,Victor Johnson,Finance,63725,victor.johnson@example.com',
#  '12,Uma Evans,Finance,48384,uma.evans@example.com',
#  '13,Mona Garcia,Sales,71456,mona.garcia@example.com',
#  '14,Mona Perez,Product,111359,mona.perez@example.com',
#  '15,David Franklin,HR,59953,david.franklin@example.com',
#  '16,Frank White,Legal,70960,frank.white@example.com',
# ...

# %%
with open("data/employees.csv","r") as f:
    text = f.readlines()
text
# Out:
# ['ID,Name,Department,Salary,Email\n',
#  '1,Ivy Clark,Operations,49662,ivy.clark@example.com\n',
#  '2,Grace Miller,IT,61923,grace.miller@example.com\n',
#  '3,Karen Xu,Sales,109685,karen.xu@example.com\n',
#  '4,Karen Evans,Finance,105968,karen.evans@example.com\n',
#  '5,Victor Underwood,Sales,87480,victor.underwood@example.com\n',
#  '6,Henry Zimmerman,Operations,105242,henry.zimmerman@example.com\n',
#  '7,Nate Turner,Engineering,115302,nate.turner@example.com\n',
#  '8,Frank Brown,Support,82794,frank.brown@example.com\n',
#  '9,Nate Xu,Finance,65897,nate.xu@example.com\n',
#  '10,Carol Garcia,Marketing,53173,carol.garcia@example.com\n',
#  '11,Victor Johnson,Finance,63725,victor.johnson@example.com\n',
#  '12,Uma Evans,Finance,48384,uma.evans@example.com\n',
#  '13,Mona Garcia,Sales,71456,mona.garcia@example.com\n',
#  '14,Mona Perez,Product,111359,mona.perez@example.com\n',
#  '15,David Franklin,HR,59953,david.franklin@example.com\n',
# ...

# %%
with open("data/employees.csv","r") as f:
    text = [ line[:-1] for line in f.readlines() ]
text
# Out:
# ['ID,Name,Department,Salary,Email',
#  '1,Ivy Clark,Operations,49662,ivy.clark@example.com',
#  '2,Grace Miller,IT,61923,grace.miller@example.com',
#  '3,Karen Xu,Sales,109685,karen.xu@example.com',
#  '4,Karen Evans,Finance,105968,karen.evans@example.com',
#  '5,Victor Underwood,Sales,87480,victor.underwood@example.com',
#  '6,Henry Zimmerman,Operations,105242,henry.zimmerman@example.com',
#  '7,Nate Turner,Engineering,115302,nate.turner@example.com',
#  '8,Frank Brown,Support,82794,frank.brown@example.com',
#  '9,Nate Xu,Finance,65897,nate.xu@example.com',
#  '10,Carol Garcia,Marketing,53173,carol.garcia@example.com',
#  '11,Victor Johnson,Finance,63725,victor.johnson@example.com',
#  '12,Uma Evans,Finance,48384,uma.evans@example.com',
#  '13,Mona Garcia,Sales,71456,mona.garcia@example.com',
#  '14,Mona Perez,Product,111359,mona.perez@example.com',
#  '15,David Franklin,HR,59953,david.franklin@example.com',
#  '16,Frank White,Legal,70960,frank.white@example.com',
# ...

# %%
with open("data/sailboat.jpg","rb") as f:
    image = f.read()

# %%
type(image)
# Out:
# bytes

# %%
with open("data/other-sailboat.jpg","wb") as f:
    f.write(image)
